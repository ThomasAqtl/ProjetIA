# %%
import os
import sys
from ChessConsole import *
if "ChessConsole" in sys.modules:
    del(sys.modules["ChessConsole"])
if "Chessgame" in sys.modules:
    del(sys.modules["Chessgame"])
if "Player" in sys.modules:
    del(sys.modules["Player"])
if "IA" in sys.modules:
    del(sys.modules["IA"])
# if "Chess" in sys.modules:
#     del(sys.modules["Player"])

# %%
if __name__ == "__main__":
    
    # ========================== GAME CHOICE ==========================
    print('Chose your game (pick number)')
    print('1. Chess')
    print('2. Tic-Tac-Toe')

    choice = input()
    while not (choice == '1' or choice == '2'):
        print('Type 1 or 2 to chose your game')
        choice = input()

    if choice == '1':
        chosen_game = 'chess'
    elif choice == '2':
        chosen_game = 'tic-tac-toe'

    print('You picked ' + chosen_game + '.\n')

    # ========================== MODE CHOICE ==========================
    print('Chose your game mode (pick number)')
    print('1. You play vs AI')
    print('2. AI vs AI (spectate)')

    mode_choice = input()
    while not (mode_choice != '1' or mode_choice != '2'):
        print('Type 1 or 2 to chose your game mode.')
        mode_choice = input()

    # ================== GAME AND MODE ATTRIBUTION ====================
    if chosen_game == 'chess':
        if mode_choice == '1':
            console = ChessConsole('pvIA')
        elif mode_choice == '2':
            console = ChessConsole('IAvIA')
    elif chosen_game == 'tic-tac-toe':
        #TODO
        pass

    # ================== LAUNCH CHOSEN GAME CONSOLE ===================
    os.system('clear') #clear terminal
    console.cmdloop()
# Out:
# Chose your game (pick number)
# 1. Chess
# 2. Tic-Tac-Toe
# 1
# You picked chess.
#
# Chose your game mode (pick number)
# 1. You play vs AI
# 2. AI vs AI (spectate)
# 1
# Type <help> to list available commands.
# Type <help><command> to see details about given command.
# Type <start> to begin a game.
#
# Chess > start
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P P P P P
# R N B Q K B N R
#
# Chess > move e2e4
# E2 -> E4 :
# r n b q k b n r
# p p p p p p p p
# . . . . . . . .
# . . . . . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# L'IA choisit le coup : d7 -> d5 :
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . p . . . .
# . . . . P . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# Chess > move e4d5
# E4 -> D5 :
# r n b q k b n r
# p p p . p p p p
# . . . . . . . .
# . . . P . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# L'IA choisit le coup : g8 -> f6 :
# r n b q k b . r
# p p p . p p p p
# . . . . . n . .
# . . . P . . . .
# . . . . . . . .
# . . . . . . . .
# P P P P . P P P
# R N B Q K B N R
#
# Chess > move d1g7
# This move is not allowed !
# Chess > move d1g5
# This move is not allowed !
# Chess > d1g4
# *** Unknown syntax: d1g4
# Chess > move d1g4
# D1 -> G4 :
# r n b q k b . r
# p p p . p p p p
# . . . . . n . .
# . . . P . . . .
# . . . . . . Q .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
# L'IA choisit le coup : d8 -> d6 :
# r n b . k b . r
# p p p . p p p p
# . . . q . n . .
# . . . P . . . .
# . . . . . . Q .
# . . . . . . . .
# P P P P . P P P
# R N B . K B N R
#
# Chess > move g1f3
# G1 -> F3 :
# r n b . k b . r
# p p p . p p p p
# . . . q . n . .
# . . . P . . . .
# . . . . . . Q .
# . . . . . N . .
# P P P P . P P P
# R N B . K B . R
#
# L'IA choisit le coup : d6 -> h2 :
# r n b . k b . r
# p p p . p p p p
# . . . . . n . .
# . . . P . . . .
# . . . . . . Q .
# . . . . . N . .
# P P P P . P P q
# R N B . K B . R
#
# Chess > move g4c8
# G4 -> C8 :
# r n Q . k b . r
# p p p . p p p p
# . . . . . n . .
# . . . P . . . .
# . . . . . . . .
# . . . . . N . .
# P P P P . P P q
# R N B . K B . R
#
# Game over : win by checkmate
